# %%
# # Run with melange conda env
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import rasterio as rs
# import cartopy.crs as ccrs
# import cartopy
# import pickle
# from PIL import Image
# import string

# %%
# img_dir='/home/robbie/Dropbox/kuka_slush'
# file='S2.tiff'

# lonlat=pickle.load(open('xytrans.p','rb'))

# with rs.open(f'{img_dir}/{file}') as src:
#     band1 = src.read(1)
#     basemap=src.read()
#     height = band1.shape[0]
#     width = band1.shape[1]
#     cols, rows = np.meshgrid(np.arange(width), np.arange(height))
#     xs, ys = rs.transform.xy(src.transform, rows, cols)
#     longrid= np.array(xs).reshape(band1.shape)
#     latgrid = np.array(ys).reshape(band1.shape)

#     pickle.dump((basemap,longrid,latgrid),open('S2.p','wb'))
